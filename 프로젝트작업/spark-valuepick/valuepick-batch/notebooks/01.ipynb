# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("explore").getOrCreate().master()

df = spark.read.parquet("/opt/spark-apps/data/indicators")
df.toPandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.appName("explore").getOrCreate().master()
#       4 df = spark.read.parquet("/opt/spark-apps/data/indicators")
#       5 df.toPandas()
#
# AttributeError: 'SparkSession' object has no attribute 'master'

# %%
df = spark.read.parquet("/opt/spark-apps/data/raw/financials")
df.toPandas()
# Out:
#       account_detail                                         account_id  \
# 0                  -                              ifrs-full_GrossProfit
# 1                  -     ifrs-full_IncomeTaxExpenseContinuingOperations
# 2                  -                 ifrs-full_OtherComprehensiveIncome
# 3                  -  ifrs-full_OtherComprehensiveIncomeThatWillBeRe...
# 4                  -  ifrs-full_GainsLossesOnExchangeDifferencesOnTr...
# ...              ...                                                ...
# 18137              -                               ifrs-full_ProfitLoss
# 18138              -  ifrs-full_ProfitLossAttributableToNoncontrolli...
# 18139              -   ifrs-full_ProfitLossAttributableToOwnersOfParent
# 18140              -                      ifrs-full_ProfitLossBeforeTax
# 18141              -                                  ifrs-full_Revenue
#
#                           account_nm bfefrmtrm_amount bfefrmtrm_nm bsns_year  \
# ...
